# %% [markdown]
# # General Dependencies for robot cell

# %%
# !pip install --upgrade pip
# !pip install ipython
# !pip install numpy
# !pip install scipy==1.8.0
# !pip install matplotlib==3.5.2
# !pip install opencv-contrib-python==4.5.5.64
# !pip install opcua
# !pip install cryptography
# !pip install pyrealsense2==2.50.0.3812
# !pip install open3d
# !pip install mediapipe==0.8.7.3
# !pip install cvzone==1.5.2
# Out:
# Requirement already satisfied: pip in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (22.1.2)
# Requirement already satisfied: ipython in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (8.4.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (3.0.29)
# Requirement already satisfied: jedi>=0.16 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (0.3.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (2.12.0)
# Requirement already satisfied: matplotlib-inline in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (0.1.3)
# Requirement already satisfied: decorator in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: backcall in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (5.3.0)
# Requirement already satisfied: colorama in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (0.4.5)
# Requirement already satisfied: pickleshare in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (62.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython) (0.2.5)
# Requirement already satisfied: executing in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from stack-data->ipython) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from stack-data->ipython) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: six in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from asttokens->stack-data->ipython) (1.16.0)
# Requirement already satisfied: numpy in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (1.22.4)
# Requirement already satisfied: scipy==1.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from scipy==1.8.0) (1.22.4)
# Requirement already satisfied: matplotlib==3.5.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\matplotlib-3.5.2-py3.9-win-amd64.egg (3.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\cycler-0.11.0-py3.9.egg (from matplotlib==3.5.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\fonttools-4.33.3-py3.9.egg (from matplotlib==3.5.2) (4.33.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\kiwisolver-1.4.3-py3.9-win-amd64.egg (from matplotlib==3.5.2) (1.4.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from matplotlib==3.5.2) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from matplotlib==3.5.2) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\pillow-9.1.1-py3.9-win-amd64.egg (from matplotlib==3.5.2) (9.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from matplotlib==3.5.2) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from matplotlib==3.5.2) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.5.2) (1.16.0)
# Requirement already satisfied: opencv-contrib-python==4.5.5.64 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (4.5.5.64)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from opencv-contrib-python==4.5.5.64) (1.22.4)
# Requirement already satisfied: opcua in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (0.98.13)
# Requirement already satisfied: lxml in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\lxml-4.9.0-py3.9-win-amd64.egg (from opcua) (4.9.0)
# Requirement already satisfied: pytz in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\pytz-2022.1-py3.9.egg (from opcua) (2022.1)
# Requirement already satisfied: python-dateutil in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from opcua) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from python-dateutil->opcua) (1.16.0)
# Requirement already satisfied: cryptography in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (37.0.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from cryptography) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from cffi>=1.12->cryptography) (2.21)
# Requirement already satisfied: pyrealsense2==2.50.0.3812 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (2.50.0.3812)
# Requirement already satisfied: open3d in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (0.15.1)
# Requirement already satisfied: pygments>=2.7.4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from open3d) (2.12.0)
# Requirement already satisfied: ipywidgets>=7.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from open3d) (7.7.0)
# Requirement already satisfied: setuptools>=40.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from open3d) (62.6.0)
# Requirement already satisfied: wheel>=0.36.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from open3d) (0.37.1)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from open3d) (1.22.4)
# Requirement already satisfied: jupyterlab==3.*,>=3.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from open3d) (3.4.3)
# Requirement already satisfied: jupyter-packaging~=0.10 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from open3d) (0.12.2)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (6.1)
# Requirement already satisfied: jinja2>=2.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (3.1.2)
# Requirement already satisfied: jupyterlab-server~=2.10 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (2.14.0)
# Requirement already satisfied: nbclassic~=0.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (0.3.7)
# Requirement already satisfied: packaging in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (21.3)
# Requirement already satisfied: ipython in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (8.4.0)
# Requirement already satisfied: jupyter-server~=1.16 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (1.17.1)
# Requirement already satisfied: jupyter-core in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyterlab==3.*,>=3.0.0->open3d) (4.10.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipywidgets>=7.6.0->open3d) (3.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipywidgets>=7.6.0->open3d) (5.3.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipywidgets>=7.6.0->open3d) (1.1.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipywidgets>=7.6.0->open3d) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipywidgets>=7.6.0->open3d) (5.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipywidgets>=7.6.0->open3d) (6.15.0)
# Requirement already satisfied: deprecation in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-packaging~=0.10->open3d) (2.1.0)
# Requirement already satisfied: tomlkit in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-packaging~=0.10->open3d) (0.11.0)
# Requirement already satisfied: nest-asyncio in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (1.5.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (0.1.3)
# Requirement already satisfied: debugpy>=1.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (1.6.0)
# Requirement already satisfied: psutil in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (5.9.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (23.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.18.1)
# Requirement already satisfied: backcall in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (3.0.29)
# Requirement already satisfied: stack-data in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.3.0)
# Requirement already satisfied: decorator in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (5.1.1)
# Requirement already satisfied: colorama in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.4.5)
# Requirement already satisfied: pickleshare in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.7.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jinja2>=2.1->jupyterlab==3.*,>=3.0.0->open3d) (2.1.1)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (6.5.0)
# Requirement already satisfied: prometheus-client in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (0.14.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (3.6.1)
# Requirement already satisfied: websocket-client in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (1.3.3)
# Requirement already satisfied: argon2-cffi in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (0.15.0)
# Requirement already satisfied: Send2Trash in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (1.8.0)
# Requirement already satisfied: pywinpty in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (2.0.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-core->jupyterlab==3.*,>=3.0.0->open3d) (304)
# Requirement already satisfied: requests in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\requests-2.28.0-py3.9.egg (from jupyterlab-server~=2.10->jupyterlab==3.*,>=3.0.0->open3d) (2.28.0)
# Requirement already satisfied: json5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab==3.*,>=3.0.0->open3d) (0.9.8)
# Requirement already satisfied: babel in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab==3.*,>=3.0.0->open3d) (2.10.3)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab==3.*,>=3.0.0->open3d) (4.6.0)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab==3.*,>=3.0.0->open3d) (4.11.4)
# Requirement already satisfied: notebook<7 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from nbclassic~=0.2->jupyterlab==3.*,>=3.0.0->open3d) (6.4.12)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from nbclassic~=0.2->jupyterlab==3.*,>=3.0.0->open3d) (0.1.0)
# Requirement already satisfied: fastjsonschema in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.0->open3d) (2.15.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from packaging->jupyterlab==3.*,>=3.0.0->open3d) (2.4.7)
# Requirement already satisfied: idna>=2.8 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (3.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from importlib-metadata>=3.6->jupyterlab-server~=2.10->jupyterlab==3.*,>=3.0.0->open3d) (3.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jedi>=0.16->ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab==3.*,>=3.0.0->open3d) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab==3.*,>=3.0.0->open3d) (0.18.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (0.2.2)
# Requirement already satisfied: tinycss2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (1.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (0.6.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (0.8.4)
# Requirement already satisfied: bleach in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (5.0.0)
# Requirement already satisfied: defusedxml in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (1.5.0)
# Requirement already satisfied: wcwidth in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from argon2-cffi->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\pytz-2022.1-py3.9.egg (from babel->jupyterlab-server~=2.10->jupyterlab==3.*,>=3.0.0->open3d) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab==3.*,>=3.0.0->open3d) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab==3.*,>=3.0.0->open3d) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab==3.*,>=3.0.0->open3d) (1.26.9)
# Requirement already satisfied: pure-eval in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from stack-data->ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.2.2)
# Requirement already satisfied: executing in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from stack-data->ipython->jupyterlab==3.*,>=3.0.0->open3d) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from stack-data->ipython->jupyterlab==3.*,>=3.0.0->open3d) (2.0.5)
# Requirement already satisfied: six>=1.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->open3d) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab==3.*,>=3.0.0->open3d) (2.21)
# Collecting mediapipe==0.8.7.3
#   Using cached mediapipe-0.8.7.3-cp39-cp39-win_amd64.whl (46.3 MB)
# Requirement already satisfied: matplotlib in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\matplotlib-3.5.2-py3.9-win-amd64.egg (from mediapipe==0.8.7.3) (3.5.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from mediapipe==0.8.7.3) (4.5.5.64)
# Requirement already satisfied: wheel in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from mediapipe==0.8.7.3) (0.37.1)
# Requirement already satisfied: absl-py in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from mediapipe==0.8.7.3) (1.1.0)
# Requirement already satisfied: protobuf>=3.11.4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from mediapipe==0.8.7.3) (3.19.4)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from mediapipe==0.8.7.3) (21.4.0)
# Requirement already satisfied: numpy in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from mediapipe==0.8.7.3) (1.22.4)
# Requirement already satisfied: six in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from mediapipe==0.8.7.3) (1.16.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\cycler-0.11.0-py3.9.egg (from matplotlib->mediapipe==0.8.7.3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\fonttools-4.33.3-py3.9.egg (from matplotlib->mediapipe==0.8.7.3) (4.33.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\kiwisolver-1.4.3-py3.9-win-amd64.egg (from matplotlib->mediapipe==0.8.7.3) (1.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from matplotlib->mediapipe==0.8.7.3) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\pillow-9.1.1-py3.9-win-amd64.egg (from matplotlib->mediapipe==0.8.7.3) (9.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from matplotlib->mediapipe==0.8.7.3) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from matplotlib->mediapipe==0.8.7.3) (2.8.2)
# Installing collected packages: mediapipe
#   Attempting uninstall: mediapipe
#     Found existing installation: mediapipe 0.8.10
#     Uninstalling mediapipe-0.8.10:
#       Successfully uninstalled mediapipe-0.8.10
# Successfully installed mediapipe-0.8.7.3
# Requirement already satisfied: cvzone==1.5.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (1.5.2)
# Requirement already satisfied: opencv-python in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\opencv_python-4.6.0.66-py3.9-win-amd64.egg (from cvzone==1.5.2) (4.6.0.66)
# Requirement already satisfied: numpy in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from cvzone==1.5.2) (1.22.4)

# %% [markdown]
# # Install dependencies for Tensorflow

# %%
# !pip install ipython
# !pip install --upgrade pip
# !pip install opencv-contrib-python==4.5.5.64
# !pip install numpy
# !pip install opt_einsum
# !pip install gast
# !pip install astunparse
# !pip install flatbuffers
# !pip install pyparsing==2.4.7
# !pip install tensorflow==2.8.0
# !pip install tensorflow-gpu==2.8.0
# !pip install tf-models-official==2.8.0
# !pip install tensorflow-estimator==2.8.0
# !pip install tensorflow-text==2.8.2
# Out:
# Requirement already satisfied: ipython in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (8.4.0)
# Requirement already satisfied: matplotlib-inline in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (0.1.3)
# Requirement already satisfied: pickleshare in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (0.7.5)
# Requirement already satisfied: colorama in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (0.4.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (2.12.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (58.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (0.18.1)
# Requirement already satisfied: decorator in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (3.0.29)
# Requirement already satisfied: backcall in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (0.3.0)
# Requirement already satisfied: traitlets>=5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from ipython) (5.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython) (0.2.5)
# Requirement already satisfied: executing in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from stack-data->ipython) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from stack-data->ipython) (2.0.5)
# Requirement already satisfied: six in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from asttokens->stack-data->ipython) (1.16.0)
# Requirement already satisfied: pip in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (22.1.2)
# Collecting opencv-contrib-python==4.5.5.64
#   Using cached opencv_contrib_python-4.5.5.64-cp36-abi3-win_amd64.whl (42.2 MB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from opencv-contrib-python==4.5.5.64) (1.22.4)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.5.5.64
# Requirement already satisfied: numpy in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (1.22.4)
# Requirement already satisfied: opt_einsum in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (3.3.0)
# Requirement already satisfied: numpy>=1.7 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from opt_einsum) (1.22.4)
# Requirement already satisfied: gast in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (0.4.0)
# Requirement already satisfied: astunparse in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from astunparse) (0.37.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from astunparse) (1.16.0)
# Requirement already satisfied: flatbuffers in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (1.12)
# Requirement already satisfied: pyparsing==2.4.7 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (2.4.7)
# Requirement already satisfied: tensorflow==2.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (2.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (1.12)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (1.1.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\grpcio-1.47.0rc1-py3.9-win-amd64.egg (from tensorflow==2.8.0) (1.47.0rc1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (3.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (1.16.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (2.8.0.dev2021122109)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\typing_extensions-4.2.0-py3.9.egg (from tensorflow==2.8.0) (4.2.0)
# Requirement already satisfied: setuptools in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (58.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\termcolor-1.1.0-py3.9.egg (from tensorflow==2.8.0) (1.1.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (3.3.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (14.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\wrapt-1.14.1-py3.9-win-amd64.egg (from tensorflow==2.8.0) (1.14.1)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (3.19.4)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (0.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow==2.8.0) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tensorflow_io_gcs_filesystem-0.26.0-py3.9-win-amd64.egg (from tensorflow==2.8.0) (0.26.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.8.0) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\requests-2.28.0-py3.9.egg (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.28.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.1.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.11.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.26.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.2.0)
# Requirement already satisfied: tensorflow-gpu==2.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (2.8.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (3.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\termcolor-1.1.0-py3.9.egg (from tensorflow-gpu==2.8.0) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\typing_extensions-4.2.0-py3.9.egg (from tensorflow-gpu==2.8.0) (4.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\grpcio-1.47.0rc1-py3.9-win-amd64.egg (from tensorflow-gpu==2.8.0) (1.47.0rc1)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (1.12)
# Requirement already satisfied: setuptools in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (58.1.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (14.0.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tensorflow_io_gcs_filesystem-0.26.0-py3.9-win-amd64.egg (from tensorflow-gpu==2.8.0) (0.26.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\wrapt-1.14.1-py3.9-win-amd64.egg (from tensorflow-gpu==2.8.0) (1.14.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (1.1.2)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (3.3.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (2.8.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (3.19.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (1.22.4)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (2.8.0.dev2021122109)
# Requirement already satisfied: gast>=0.2.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-gpu==2.8.0) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu==2.8.0) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.1.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\requests-2.28.0-py3.9.egg (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.28.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (4.11.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (1.26.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.2.0)
# Requirement already satisfied: tf-models-official==2.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (2.8.0)
# Requirement already satisfied: oauth2client in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\oauth2client-4.1.3-py3.9.egg (from tf-models-official==2.8.0) (4.1.3)
# Requirement already satisfied: pycocotools in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\pycocotools-2.0.4-py3.9-win-amd64.egg (from tf-models-official==2.8.0) (2.0.4)
# Requirement already satisfied: psutil>=5.4.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tf-models-official==2.8.0) (5.9.1)
# Requirement already satisfied: tensorflow-addons in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tensorflow_addons-0.17.1-py3.9-win-amd64.egg (from tf-models-official==2.8.0) (0.17.1)
# Requirement already satisfied: six in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tf-models-official==2.8.0) (1.16.0)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tf-models-official==2.8.0) (1.22.4)
# Requirement already satisfied: google-api-python-client>=1.6.7 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\google_api_python_client-2.51.0-py3.9.egg (from tf-models-official==2.8.0) (2.51.0)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\pyyaml-5.4.1-py3.9-win-amd64.egg (from tf-models-official==2.8.0) (5.4.1)
# Requirement already satisfied: tensorflow~=2.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tf-models-official==2.8.0) (2.8.0)
# Requirement already satisfied: opencv-python-headless in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\opencv_python_headless-4.6.0.66-py3.9-win-amd64.egg (from tf-models-official==2.8.0) (4.6.0.66)
# Requirement already satisfied: seqeval in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\seqeval-1.2.2-py3.9.egg (from tf-models-official==2.8.0) (1.2.2)
# Requirement already satisfied: kaggle>=1.3.9 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\kaggle-1.5.12-py3.9.egg (from tf-models-official==2.8.0) (1.5.12)
# Requirement already satisfied: gin-config in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\gin_config-0.5.0-py3.9.egg (from tf-models-official==2.8.0) (0.5.0)
# Requirement already satisfied: tensorflow-text~=2.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tf-models-official==2.8.0) (2.8.2)
# Requirement already satisfied: tensorflow-datasets in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tensorflow_datasets-4.6.0-py3.9.egg (from tf-models-official==2.8.0) (4.6.0)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tensorflow_hub-0.12.0-py3.9.egg (from tf-models-official==2.8.0) (0.12.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\scipy-1.8.1-py3.9-win-amd64.egg (from tf-models-official==2.8.0) (1.8.1)
# Requirement already satisfied: tf-slim>=1.1.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tf-models-official==2.8.0) (1.1.0)
# Requirement already satisfied: Cython in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\cython-3.0.0a10-py3.9.egg (from tf-models-official==2.8.0) (3.0.0a10)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\py_cpuinfo-8.0.0-py3.9.egg (from tf-models-official==2.8.0) (8.0.0)
# Requirement already satisfied: sentencepiece in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\sentencepiece-0.1.96-py3.9-win-amd64.egg (from tf-models-official==2.8.0) (0.1.96)
# Requirement already satisfied: matplotlib in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\matplotlib-3.5.2-py3.9-win-amd64.egg (from tf-models-official==2.8.0) (3.5.2)
# Requirement already satisfied: sacrebleu in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\sacrebleu-2.1.0-py3.9.egg (from tf-models-official==2.8.0) (2.1.0)
# Requirement already satisfied: pandas>=0.22.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\pandas-1.4.2-py3.9-win-amd64.egg (from tf-models-official==2.8.0) (1.4.2)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tensorflow_model_optimization-0.7.2-py3.9.egg (from tf-models-official==2.8.0) (0.7.2)
# Requirement already satisfied: Pillow in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\pillow-9.1.1-py3.9-win-amd64.egg (from tf-models-official==2.8.0) (9.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\google_api_core-2.8.2-py3.9.egg (from google-api-python-client>=1.6.7->tf-models-official==2.8.0) (2.8.2)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\google_auth_httplib2-0.1.0-py3.9.egg (from google-api-python-client>=1.6.7->tf-models-official==2.8.0) (0.1.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.16.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0) (2.8.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\httplib2-0.20.4-py3.9.egg (from google-api-python-client>=1.6.7->tf-models-official==2.8.0) (0.20.4)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\uritemplate-4.1.1-py3.9.egg (from google-api-python-client>=1.6.7->tf-models-official==2.8.0) (4.1.1)
# Requirement already satisfied: certifi in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0) (2022.6.15)
# Requirement already satisfied: python-dateutil in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0) (2.8.2)
# Requirement already satisfied: requests in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\requests-2.28.0-py3.9.egg (from kaggle>=1.3.9->tf-models-official==2.8.0) (2.28.0)
# Requirement already satisfied: tqdm in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tqdm-4.64.0-py3.9.egg (from kaggle>=1.3.9->tf-models-official==2.8.0) (4.64.0)
# Requirement already satisfied: python-slugify in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\python_slugify-6.1.2-py3.9.egg (from kaggle>=1.3.9->tf-models-official==2.8.0) (6.1.2)
# Requirement already satisfied: urllib3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0) (1.26.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\pytz-2022.1-py3.9.egg (from pandas>=0.22.0->tf-models-official==2.8.0) (2022.1)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (2.8.0.dev2021122109)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\typing_extensions-4.2.0-py3.9.egg (from tensorflow~=2.8.0->tf-models-official==2.8.0) (4.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (3.19.4)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\termcolor-1.1.0-py3.9.egg (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.1.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (0.4.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\grpcio-1.47.0rc1-py3.9-win-amd64.egg (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.47.0rc1)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (2.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\wrapt-1.14.1-py3.9-win-amd64.egg (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.14.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.1.2)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (2.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (3.7.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (14.0.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tensorflow_io_gcs_filesystem-0.26.0-py3.9-win-amd64.egg (from tensorflow~=2.8.0->tf-models-official==2.8.0) (0.26.0)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.12)
# Requirement already satisfied: setuptools in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (58.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0) (1.6.3)
# Requirement already satisfied: dm-tree~=0.1.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\dm_tree-0.1.7-py3.9-win-amd64.egg (from tensorflow-model-optimization>=0.4.1->tf-models-official==2.8.0) (0.1.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\cycler-0.11.0-py3.9.egg (from matplotlib->tf-models-official==2.8.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\fonttools-4.33.3-py3.9.egg (from matplotlib->tf-models-official==2.8.0) (4.33.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\kiwisolver-1.4.3-py3.9-win-amd64.egg (from matplotlib->tf-models-official==2.8.0) (1.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from matplotlib->tf-models-official==2.8.0) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from matplotlib->tf-models-official==2.8.0) (2.4.7)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from oauth2client->tf-models-official==2.8.0) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from oauth2client->tf-models-official==2.8.0) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from oauth2client->tf-models-official==2.8.0) (4.8)
# Requirement already satisfied: colorama in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from sacrebleu->tf-models-official==2.8.0) (0.4.5)
# Requirement already satisfied: portalocker in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\portalocker-2.4.0-py3.9.egg (from sacrebleu->tf-models-official==2.8.0) (2.4.0)
# Requirement already satisfied: regex in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\regex-2022.6.2-py3.9-win-amd64.egg (from sacrebleu->tf-models-official==2.8.0) (2022.6.2)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tabulate-0.8.9-py3.9.egg (from sacrebleu->tf-models-official==2.8.0) (0.8.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\scikit_learn-1.1.1-py3.9-win-amd64.egg (from seqeval->tf-models-official==2.8.0) (1.1.1)
# Requirement already satisfied: typeguard>=2.7 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\typeguard-2.13.3-py3.9.egg (from tensorflow-addons->tf-models-official==2.8.0) (2.13.3)
# Requirement already satisfied: dill in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\dill-0.3.1.1-py3.9.egg (from tensorflow-datasets->tf-models-official==2.8.0) (0.3.1.1)
# Requirement already satisfied: etils[epath] in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\etils-0.6.0-py3.9.egg (from tensorflow-datasets->tf-models-official==2.8.0) (0.6.0)
# Requirement already satisfied: promise in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\promise-2.3-py3.9.egg (from tensorflow-datasets->tf-models-official==2.8.0) (2.3)
# Requirement already satisfied: tensorflow-metadata in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tensorflow_metadata-1.8.0-py3.9.egg (from tensorflow-datasets->tf-models-official==2.8.0) (1.8.0)
# Requirement already satisfied: toml in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\toml-0.10.2-py3.9.egg (from tensorflow-datasets->tf-models-official==2.8.0) (0.10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from astunparse>=1.6.0->tensorflow~=2.8.0->tf-models-official==2.8.0) (0.37.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\googleapis_common_protos-1.56.3b1-py3.9.egg (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (1.56.3b1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0) (5.2.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests->kaggle>=1.3.9->tf-models-official==2.8.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests->kaggle>=1.3.9->tf-models-official==2.8.0) (3.3)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\joblib-1.1.0-py3.9.egg (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\threadpoolctl-3.1.0-py3.9.egg (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0) (3.1.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (2.1.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (3.3.7)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (1.8.1)
# Requirement already satisfied: importlib_resources in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\importlib_resources-5.8.0-py3.9.egg (from etils[epath]->tensorflow-datasets->tf-models-official==2.8.0) (5.8.0)
# Requirement already satisfied: zipp in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from etils[epath]->tensorflow-datasets->tf-models-official==2.8.0) (3.8.0)
# Requirement already satisfied: pywin32>=226 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from portalocker->sacrebleu->tf-models-official==2.8.0) (304)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\text_unidecode-1.3-py3.9.egg (from python-slugify->kaggle>=1.3.9->tf-models-official==2.8.0) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (4.11.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0) (3.2.0)
# Requirement already satisfied: tensorflow-estimator==2.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (2.8.0)
# Requirement already satisfied: tensorflow-text==2.8.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (2.8.2)
# Requirement already satisfied: tensorflow<2.9,>=2.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow-text==2.8.2) (2.8.0)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tensorflow_hub-0.12.0-py3.9.egg (from tensorflow-text==2.8.2) (0.12.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (3.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (3.19.4)
# Requirement already satisfied: six>=1.12.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\grpcio-1.47.0rc1-py3.9-win-amd64.egg (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (1.47.0rc1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\typing_extensions-4.2.0-py3.9.egg (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (4.2.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (0.4.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (2.8.0.dev2021122109)
# Requirement already satisfied: setuptools in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (58.1.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (1.22.4)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (0.2.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (14.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\wrapt-1.14.1-py3.9-win-amd64.egg (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (1.14.1)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (1.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (1.12)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\termcolor-1.1.0-py3.9.egg (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (1.1.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tensorflow_io_gcs_filesystem-0.26.0-py3.9-win-amd64.egg (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (0.26.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (2.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (2.8.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (2.1.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (3.3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\requests-2.28.0-py3.9.egg (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (2.28.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (4.11.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (1.26.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text==2.8.2) (3.2.0)

# %%
import os

# %%
paths = {
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %%
if os.name=='nt':
    # !pip install wget
    import wget
# Out:
# Collecting wget
#   Using cached wget-3.2-py3-none-any.whl
# Installing collected packages: wget
# Successfully installed wget-3.2
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}
# Out:
# Cloning into 'Tensorflow\models'...
# Updating files:  87% (2681/3075)
# Updating files:  88% (2706/3075)
# Updating files:  89% (2737/3075)
# Updating files:  90% (2768/3075)
# Updating files:  91% (2799/3075)
# Updating files:  92% (2829/3075)
# Updating files:  93% (2860/3075)
# Updating files:  94% (2891/3075)
# Updating files:  95% (2922/3075)
# Updating files:  96% (2952/3075)
# Updating files:  97% (2983/3075)
# Updating files:  98% (3014/3075)
# Updating files:  99% (3045/3075)
# Updating files: 100% (3075/3075)
# Updating files: 100% (3075/3075), done.

# %%
# Install Tensorflow Object Detection

if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
#         1 file(s) moved.
#         1 file(s) copied.
# running build
# running build_py
# copying object_detection\protos\anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\argmax_matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\bipartite_matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\box_predictor_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\calibration_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\center_net_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\eval_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\faster_rcnn_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\faster_rcnn_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\flexible_grid_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\fpn_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\graph_rewriter_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\grid_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\hyperparams_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\image_resizer_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\input_reader_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\keypoint_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\losses_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\mean_stddev_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\model_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\multiscale_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\optimizer_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\pipeline_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\post_processing_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\preprocessor_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\region_similarity_calculator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\square_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\ssd_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\ssd_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\string_int_label_map_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\target_assigner_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\train_pb2.py -> build\lib\object_detection\protos
# running egg_info
# writing object_detection.egg-info\PKG-INFO
# writing dependency_links to object_detection.egg-info\dependency_links.txt
# writing requirements to object_detection.egg-info\requires.txt
# writing top-level names to object_detection.egg-info\top_level.txt
# reading manifest file 'object_detection.egg-info\SOURCES.txt'
# writing manifest file 'object_detection.egg-info\SOURCES.txt'
# running install
# running bdist_egg
# running egg_info
# writing object_detection.egg-info\PKG-INFO
# writing dependency_links to object_detection.egg-info\dependency_links.txt
# writing requirements to object_detection.egg-info\requires.txt
# writing top-level names to object_detection.egg-info\top_level.txt
# reading manifest file 'object_detection.egg-info\SOURCES.txt'
# writing manifest file 'object_detection.egg-info\SOURCES.txt'
# installing library code to build\bdist.win-amd64\egg
# running install_lib
# running build_py
# creating build\bdist.win-amd64\egg
# creating build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\build_imagenet_data.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\cifar10.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\dataset_factory.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\dataset_utils.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\download_and_convert_cifar10.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\download_and_convert_flowers.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\download_and_convert_mnist.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\download_and_convert_visualwakewords.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\download_and_convert_visualwakewords_lib.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\flowers.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\imagenet.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\mnist.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\preprocess_imagenet_validation_data.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\process_bounding_boxes.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\visualwakewords.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\__init__.py -> build\bdist.win-amd64\egg\datasets
# creating build\bdist.win-amd64\egg\deployment
# copying build\lib\deployment\model_deploy.py -> build\bdist.win-amd64\egg\deployment
# copying build\lib\deployment\model_deploy_test.py -> build\bdist.win-amd64\egg\deployment
# copying build\lib\deployment\__init__.py -> build\bdist.win-amd64\egg\deployment
# creating build\bdist.win-amd64\egg\nets
# copying build\lib\nets\alexnet.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\alexnet_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\cifarnet.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\cyclegan.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\cyclegan_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\dcgan.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\dcgan_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\i3d.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\i3d_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\i3d_utils.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\inception.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\inception_resnet_v2.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\inception_resnet_v2_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\inception_utils.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\inception_v1.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\inception_v1_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\inception_v2.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\inception_v2_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\inception_v3.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\inception_v3_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\inception_v4.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\inception_v4_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\lenet.py -> build\bdist.win-amd64\egg\nets
# creating build\bdist.win-amd64\egg\nets\mobilenet
# copying build\lib\nets\mobilenet\conv_blocks.py -> build\bdist.win-amd64\egg\nets\mobilenet
# copying build\lib\nets\mobilenet\mobilenet.py -> build\bdist.win-amd64\egg\nets\mobilenet
# copying build\lib\nets\mobilenet\mobilenet_v2.py -> build\bdist.win-amd64\egg\nets\mobilenet
# copying build\lib\nets\mobilenet\mobilenet_v2_test.py -> build\bdist.win-amd64\egg\nets\mobilenet
# copying build\lib\nets\mobilenet\mobilenet_v3.py -> build\bdist.win-amd64\egg\nets\mobilenet
# copying build\lib\nets\mobilenet\mobilenet_v3_test.py -> build\bdist.win-amd64\egg\nets\mobilenet
# copying build\lib\nets\mobilenet\__init__.py -> build\bdist.win-amd64\egg\nets\mobilenet
# copying build\lib\nets\mobilenet_v1.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\mobilenet_v1_eval.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\mobilenet_v1_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\mobilenet_v1_train.py -> build\bdist.win-amd64\egg\nets
# creating build\bdist.win-amd64\egg\nets\nasnet
# copying build\lib\nets\nasnet\nasnet.py -> build\bdist.win-amd64\egg\nets\nasnet
# copying build\lib\nets\nasnet\nasnet_test.py -> build\bdist.win-amd64\egg\nets\nasnet
# copying build\lib\nets\nasnet\nasnet_utils.py -> build\bdist.win-amd64\egg\nets\nasnet
# copying build\lib\nets\nasnet\nasnet_utils_test.py -> build\bdist.win-amd64\egg\nets\nasnet
# copying build\lib\nets\nasnet\pnasnet.py -> build\bdist.win-amd64\egg\nets\nasnet
# copying build\lib\nets\nasnet\pnasnet_test.py -> build\bdist.win-amd64\egg\nets\nasnet
# copying build\lib\nets\nasnet\__init__.py -> build\bdist.win-amd64\egg\nets\nasnet
# copying build\lib\nets\nets_factory.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\nets_factory_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\overfeat.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\overfeat_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\pix2pix.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\pix2pix_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\post_training_quantization.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\resnet_utils.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\resnet_v1.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\resnet_v1_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\resnet_v2.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\resnet_v2_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\s3dg.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\s3dg_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\vgg.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\vgg_test.py -> build\bdist.win-amd64\egg\nets
# copying build\lib\nets\__init__.py -> build\bdist.win-amd64\egg\nets
# creating build\bdist.win-amd64\egg\object_detection
# creating build\bdist.win-amd64\egg\object_detection\anchor_generators
# copying build\lib\object_detection\anchor_generators\flexible_grid_anchor_generator.py -> build\bdist.win-amd64\egg\object_detection\anchor_generators
# copying build\lib\object_detection\anchor_generators\flexible_grid_anchor_generator_test.py -> build\bdist.win-amd64\egg\object_detection\anchor_generators
# copying build\lib\object_detection\anchor_generators\grid_anchor_generator.py -> build\bdist.win-amd64\egg\object_detection\anchor_generators
# copying build\lib\object_detection\anchor_generators\grid_anchor_generator_test.py -> build\bdist.win-amd64\egg\object_detection\anchor_generators
# copying build\lib\object_detection\anchor_generators\multiple_grid_anchor_generator.py -> build\bdist.win-amd64\egg\object_detection\anchor_generators
# copying build\lib\object_detection\anchor_generators\multiple_grid_anchor_generator_test.py -> build\bdist.win-amd64\egg\object_detection\anchor_generators
# copying build\lib\object_detection\anchor_generators\multiscale_grid_anchor_generator.py -> build\bdist.win-amd64\egg\object_detection\anchor_generators
# copying build\lib\object_detection\anchor_generators\multiscale_grid_anchor_generator_test.py -> build\bdist.win-amd64\egg\object_detection\anchor_generators
# copying build\lib\object_detection\anchor_generators\__init__.py -> build\bdist.win-amd64\egg\object_detection\anchor_generators
# creating build\bdist.win-amd64\egg\object_detection\box_coders
# copying build\lib\object_detection\box_coders\faster_rcnn_box_coder.py -> build\bdist.win-amd64\egg\object_detection\box_coders
# copying build\lib\object_detection\box_coders\faster_rcnn_box_coder_test.py -> build\bdist.win-amd64\egg\object_detection\box_coders
# copying build\lib\object_detection\box_coders\keypoint_box_coder.py -> build\bdist.win-amd64\egg\object_detection\box_coders
# copying build\lib\object_detection\box_coders\keypoint_box_coder_test.py -> build\bdist.win-amd64\egg\object_detection\box_coders
# copying build\lib\object_detection\box_coders\mean_stddev_box_coder.py -> build\bdist.win-amd64\egg\object_detection\box_coders
# copying build\lib\object_detection\box_coders\mean_stddev_box_coder_test.py -> build\bdist.win-amd64\egg\object_detection\box_coders
# copying build\lib\object_detection\box_coders\square_box_coder.py -> build\bdist.win-amd64\egg\object_detection\box_coders
# copying build\lib\object_detection\box_coders\square_box_coder_test.py -> build\bdist.win-amd64\egg\object_detection\box_coders
# copying build\lib\object_detection\box_coders\__init__.py -> build\bdist.win-amd64\egg\object_detection\box_coders
# creating build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\anchor_generator_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\anchor_generator_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\box_coder_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\box_coder_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\box_predictor_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\box_predictor_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\calibration_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\calibration_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\dataset_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\dataset_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\decoder_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\decoder_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\graph_rewriter_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\graph_rewriter_builder_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\hyperparams_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\hyperparams_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\image_resizer_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\image_resizer_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\input_reader_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\input_reader_builder_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\losses_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\losses_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\matcher_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\matcher_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\model_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\model_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\model_builder_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\model_builder_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\optimizer_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\optimizer_builder_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\optimizer_builder_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\post_processing_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\post_processing_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\preprocessor_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\preprocessor_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\region_similarity_calculator_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\region_similarity_calculator_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\target_assigner_builder.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\target_assigner_builder_test.py -> build\bdist.win-amd64\egg\object_detection\builders
# copying build\lib\object_detection\builders\__init__.py -> build\bdist.win-amd64\egg\object_detection\builders
# creating build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\anchor_generator.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\balanced_positive_negative_sampler.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\balanced_positive_negative_sampler_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\batcher.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\batcher_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\batch_multiclass_nms_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\box_coder.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\box_coder_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\box_list.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\box_list_ops.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\box_list_ops_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\box_list_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\box_predictor.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\class_agnostic_nms_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\data_decoder.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\data_parser.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\densepose_ops.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\densepose_ops_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\freezable_batch_norm.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\freezable_batch_norm_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\freezable_sync_batch_norm.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\keypoint_ops.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\keypoint_ops_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\losses.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\losses_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\matcher.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\matcher_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\minibatch_sampler.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\minibatch_sampler_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\model.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\model_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\multiclass_nms_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\post_processing.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\prefetcher.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\prefetcher_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\preprocessor.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\preprocessor_cache.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\preprocessor_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\region_similarity_calculator.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\region_similarity_calculator_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\standard_fields.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\target_assigner.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\target_assigner_test.py -> build\bdist.win-amd64\egg\object_detection\core
# copying build\lib\object_detection\core\__init__.py -> build\bdist.win-amd64\egg\object_detection\core
# creating build\bdist.win-amd64\egg\object_detection\dataset_tools
# creating build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn
# copying build\lib\object_detection\dataset_tools\context_rcnn\add_context_to_examples.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn
# copying build\lib\object_detection\dataset_tools\context_rcnn\add_context_to_examples_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn
# copying build\lib\object_detection\dataset_tools\context_rcnn\create_cococameratraps_tfexample_main.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn
# copying build\lib\object_detection\dataset_tools\context_rcnn\create_cococameratraps_tfexample_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn
# copying build\lib\object_detection\dataset_tools\context_rcnn\generate_detection_data.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn
# copying build\lib\object_detection\dataset_tools\context_rcnn\generate_detection_data_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn
# copying build\lib\object_detection\dataset_tools\context_rcnn\generate_embedding_data.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn
# copying build\lib\object_detection\dataset_tools\context_rcnn\generate_embedding_data_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn
# copying build\lib\object_detection\dataset_tools\context_rcnn\__init__.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools\context_rcnn
# copying build\lib\object_detection\dataset_tools\create_ava_actions_tf_record.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\create_coco_tf_record.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\create_coco_tf_record_test.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\create_kitti_tf_record.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\create_kitti_tf_record_test.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\create_oid_tf_record.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\create_pascal_tf_record.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\create_pascal_tf_record_test.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\create_pet_tf_record.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\oid_hierarchical_labels_expansion.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\oid_hierarchical_labels_expansion_test.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\oid_tfrecord_creation.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\oid_tfrecord_creation_test.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\seq_example_util.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\seq_example_util_test.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\tf_record_creation_util.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\tf_record_creation_util_test.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# copying build\lib\object_detection\dataset_tools\__init__.py -> build\bdist.win-amd64\egg\object_detection\dataset_tools
# creating build\bdist.win-amd64\egg\object_detection\data_decoders
# copying build\lib\object_detection\data_decoders\tf_example_decoder.py -> build\bdist.win-amd64\egg\object_detection\data_decoders
# copying build\lib\object_detection\data_decoders\tf_example_decoder_test.py -> build\bdist.win-amd64\egg\object_detection\data_decoders
# copying build\lib\object_detection\data_decoders\tf_sequence_example_decoder.py -> build\bdist.win-amd64\egg\object_detection\data_decoders
# copying build\lib\object_detection\data_decoders\tf_sequence_example_decoder_test.py -> build\bdist.win-amd64\egg\object_detection\data_decoders
# copying build\lib\object_detection\data_decoders\__init__.py -> build\bdist.win-amd64\egg\object_detection\data_decoders
# copying build\lib\object_detection\eval_util.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\eval_util_test.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\exporter.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\exporter_lib_tf2_test.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\exporter_lib_v2.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\exporter_main_v2.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\exporter_tf1_test.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\export_inference_graph.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\export_tflite_graph_lib_tf2.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\export_tflite_graph_lib_tf2_test.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\export_tflite_graph_tf2.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\export_tflite_ssd_graph.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\export_tflite_ssd_graph_lib.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\export_tflite_ssd_graph_lib_tf1_test.py -> build\bdist.win-amd64\egg\object_detection
# creating build\bdist.win-amd64\egg\object_detection\inference
# copying build\lib\object_detection\inference\detection_inference.py -> build\bdist.win-amd64\egg\object_detection\inference
# copying build\lib\object_detection\inference\detection_inference_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\inference
# copying build\lib\object_detection\inference\infer_detections.py -> build\bdist.win-amd64\egg\object_detection\inference
# copying build\lib\object_detection\inference\__init__.py -> build\bdist.win-amd64\egg\object_detection\inference
# copying build\lib\object_detection\inputs.py -> build\bdist.win-amd64\egg\object_detection
# copying build\lib\object_detection\inputs_test.py -> build\bdist.win-amd64\egg\object_detection
# creating build\bdist.win-amd64\egg\object_detection\legacy
# copying build\lib\object_detection\legacy\eval.py -> build\bdist.win-amd64\egg\object_detection\legacy
# copying build\lib\object_detection\legacy\evaluator.py -> build\bdist.win-amd64\egg\object_detection\legacy
# copying build\lib\object_detection\legacy\train.py -> build\bdist.win-amd64\egg\object_detection\legacy
# copying build\lib\object_detection\legacy\trainer.py -> build\bdist.win-amd64\egg\object_detection\legacy
# copying build\lib\object_detection\legacy\trainer_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\legacy
# copying build\lib\object_detection\legacy\__init__.py -> build\bdist.win-amd64\egg\object_detection\legacy
# creating build\bdist.win-amd64\egg\object_detection\matchers
# copying build\lib\object_detection\matchers\argmax_matcher.py -> build\bdist.win-amd64\egg\object_detection\matchers
# copying build\lib\object_detection\matchers\argmax_matcher_test.py -> build\bdist.win-amd64\egg\object_detection\matchers
# copying build\lib\object_detection\matchers\bipartite_matcher.py -> build\bdist.win-amd64\egg\object_detection\matchers
# copying build\lib\object_detection\matchers\bipartite_matcher_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\matchers
# copying build\lib\object_detection\matchers\hungarian_matcher.py -> build\bdist.win-amd64\egg\object_detection\matchers
# copying build\lib\object_detection\matchers\hungarian_matcher_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\matchers
# copying build\lib\object_detection\matchers\__init__.py -> build\bdist.win-amd64\egg\object_detection\matchers
# creating build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\center_net_meta_arch.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\center_net_meta_arch_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\context_rcnn_lib.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\context_rcnn_lib_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\context_rcnn_lib_tf2.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\context_rcnn_lib_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\context_rcnn_meta_arch.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\context_rcnn_meta_arch_test.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\deepmac_meta_arch.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\deepmac_meta_arch_test.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\faster_rcnn_meta_arch.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\faster_rcnn_meta_arch_test.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\faster_rcnn_meta_arch_test_lib.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\rfcn_meta_arch.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\rfcn_meta_arch_test.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\ssd_meta_arch.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\ssd_meta_arch_test.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\ssd_meta_arch_test_lib.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# copying build\lib\object_detection\meta_architectures\__init__.py -> build\bdist.win-amd64\egg\object_detection\meta_architectures
# creating build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\calibration_evaluation.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\calibration_evaluation_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\calibration_metrics.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\calibration_metrics_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\coco_evaluation.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\coco_evaluation_test.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\coco_tools.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\coco_tools_test.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\io_utils.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\lvis_evaluation.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\lvis_evaluation_test.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\lvis_tools.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\lvis_tools_test.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\offline_eval_map_corloc.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\offline_eval_map_corloc_test.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\oid_challenge_evaluation.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\oid_challenge_evaluation_utils.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\oid_challenge_evaluation_utils_test.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\oid_vrd_challenge_evaluation.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\oid_vrd_challenge_evaluation_utils.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\oid_vrd_challenge_evaluation_utils_test.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\tf_example_parser.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\tf_example_parser_test.py -> build\bdist.win-amd64\egg\object_detection\metrics
# copying build\lib\object_detection\metrics\__init__.py -> build\bdist.win-amd64\egg\object_detection\metrics
# creating build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\bidirectional_feature_pyramid_generators.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\bidirectional_feature_pyramid_generators_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\center_net_hourglass_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\center_net_hourglass_feature_extractor_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\center_net_mobilenet_v2_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\center_net_mobilenet_v2_feature_extractor_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\center_net_mobilenet_v2_fpn_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\center_net_mobilenet_v2_fpn_feature_extractor_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\center_net_resnet_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\center_net_resnet_feature_extractor_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\center_net_resnet_v1_fpn_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\center_net_resnet_v1_fpn_feature_extractor_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\embedded_ssd_mobilenet_v1_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\embedded_ssd_mobilenet_v1_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_inception_resnet_v2_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_inception_resnet_v2_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_inception_resnet_v2_keras_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_inception_resnet_v2_keras_feature_extractor_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_inception_v2_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_inception_v2_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_mobilenet_v1_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_mobilenet_v1_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_nas_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_nas_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_pnas_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_pnas_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_resnet_keras_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_resnet_keras_feature_extractor_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_resnet_v1_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_resnet_v1_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_resnet_v1_fpn_keras_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\faster_rcnn_resnet_v1_fpn_keras_feature_extractor_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\feature_map_generators.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\feature_map_generators_test.py -> build\bdist.win-amd64\egg\object_detection\models
# creating build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\convert_keras_models.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\hourglass_network.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\hourglass_network_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\inception_resnet_v2.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\inception_resnet_v2_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\mobilenet_v1.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\mobilenet_v1_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\mobilenet_v2.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\mobilenet_v2_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\model_utils.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\nonlocal_block.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\nonlocal_block_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\resnet_v1.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\resnet_v1_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\test_utils.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\keras_models\__init__.py -> build\bdist.win-amd64\egg\object_detection\models\keras_models
# copying build\lib\object_detection\models\ssd_efficientnet_bifpn_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_efficientnet_bifpn_feature_extractor_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_feature_extractor_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_inception_v2_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_inception_v2_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_inception_v3_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_inception_v3_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobiledet_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobiledet_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobilenet_edgetpu_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobilenet_edgetpu_feature_extractor_testbase.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobilenet_edgetpu_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobilenet_v1_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobilenet_v1_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobilenet_v1_feature_extractor_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobilenet_v1_fpn_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobilenet_v1_fpn_feature_extractor_tf1_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobilenet_v1_fpn_feature_extractor_tf2_test.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobilenet_v1_fpn_keras_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobilenet_v1_keras_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# copying build\lib\object_detection\models\ssd_mobilenet_v1_ppn_feature_extractor.py -> build\bdist.win-amd64\egg\object_detection\models
# ...
# requests 2.28.0 is already the active version in easy-install.pth
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\requests-2.28.0-py3.9.egg
# Searching for pymongo==3.12.3
# Best match: pymongo 3.12.3
# Processing pymongo-3.12.3-py3.9-win-amd64.egg
# pymongo 3.12.3 is already the active version in easy-install.pth
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\pymongo-3.12.3-py3.9-win-amd64.egg
# Searching for pydot==1.4.2
# Best match: pydot 1.4.2
# Processing pydot-1.4.2-py3.9.egg
# pydot 1.4.2 is already the active version in easy-install.pth
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\pydot-1.4.2-py3.9.egg
# Searching for pyarrow==7.0.0
# Best match: pyarrow 7.0.0
# Processing pyarrow-7.0.0-py3.9-win-amd64.egg
# pyarrow 7.0.0 is already the active version in easy-install.pth
# Installing plasma_store-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing plasma_store.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\pyarrow-7.0.0-py3.9-win-amd64.egg
# Searching for protobuf==3.19.4
# Best match: protobuf 3.19.4
# Adding protobuf 3.19.4 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for proto-plus==1.20.6
# Best match: proto-plus 1.20.6
# Processing proto_plus-1.20.6-py3.9.egg
# proto-plus 1.20.6 is already the active version in easy-install.pth
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\proto_plus-1.20.6-py3.9.egg
# Searching for orjson==3.7.2
# Best match: orjson 3.7.2
# Processing orjson-3.7.2-py3.9-win-amd64.egg
# orjson 3.7.2 is already the active version in easy-install.pth
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\orjson-3.7.2-py3.9-win-amd64.egg
# Searching for httplib2==0.20.4
# Best match: httplib2 0.20.4
# Processing httplib2-0.20.4-py3.9.egg
# httplib2 0.20.4 is already the active version in easy-install.pth
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\httplib2-0.20.4-py3.9.egg
# Searching for hdfs==2.7.0
# Best match: hdfs 2.7.0
# Processing hdfs-2.7.0-py3.9.egg
# hdfs 2.7.0 is already the active version in easy-install.pth
# Installing hdfscli-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing hdfscli.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing hdfscli-avro-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing hdfscli-avro.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\hdfs-2.7.0-py3.9.egg
# Searching for grpcio==1.47.0rc1
# Best match: grpcio 1.47.0rc1
# Processing grpcio-1.47.0rc1-py3.9-win-amd64.egg
# grpcio 1.47.0rc1 is already the active version in easy-install.pth
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\grpcio-1.47.0rc1-py3.9-win-amd64.egg
# Searching for fastavro==1.5.1
# Best match: fastavro 1.5.1
# Processing fastavro-1.5.1-py3.9-win-amd64.egg
# fastavro 1.5.1 is already the active version in easy-install.pth
# Installing fastavro-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing fastavro.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\fastavro-1.5.1-py3.9-win-amd64.egg
# Searching for dill==0.3.1.1
# Best match: dill 0.3.1.1
# Processing dill-0.3.1.1-py3.9.egg
# dill 0.3.1.1 is already the active version in easy-install.pth
# Installing get_objgraph script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing undill script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\dill-0.3.1.1-py3.9.egg
# Searching for crcmod==1.7
# Best match: crcmod 1.7
# Processing crcmod-1.7-py3.9-win-amd64.egg
# crcmod 1.7 is already the active version in easy-install.pth
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\crcmod-1.7-py3.9-win-amd64.egg
# Searching for cloudpickle==2.1.0
# Best match: cloudpickle 2.1.0
# Processing cloudpickle-2.1.0-py3.9.egg
# cloudpickle 2.1.0 is already the active version in easy-install.pth
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\cloudpickle-2.1.0-py3.9.egg
# Searching for wrapt==1.14.1
# Best match: wrapt 1.14.1
# Processing wrapt-1.14.1-py3.9-win-amd64.egg
# wrapt 1.14.1 is already the active version in easy-install.pth
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\wrapt-1.14.1-py3.9-win-amd64.egg
# Searching for termcolor==1.1.0
# Best match: termcolor 1.1.0
# Processing termcolor-1.1.0-py3.9.egg
# termcolor 1.1.0 is already the active version in easy-install.pth
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\termcolor-1.1.0-py3.9.egg
# Searching for tensorflow-estimator==2.9.0
# Best match: tensorflow-estimator 2.9.0
# Processing tensorflow_estimator-2.9.0-py3.9.egg
# tensorflow-estimator 2.9.0 is already the active version in easy-install.pth
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tensorflow_estimator-2.9.0-py3.9.egg
# Searching for tensorboard==2.9.1
# Best match: tensorboard 2.9.1
# Processing tensorboard-2.9.1-py3.9.egg
# tensorboard 2.9.1 is already the active version in easy-install.pth
# Installing tensorboard-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing tensorboard.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages\tensorboard-2.9.1-py3.9.egg
# Searching for setuptools==58.1.0
# Best match: setuptools 58.1.0
# Adding setuptools 58.1.0 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for opt-einsum==3.3.0
# Best match: opt-einsum 3.3.0
# Adding opt-einsum 3.3.0 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for libclang==14.0.1
# Best match: libclang 14.0.1
# Adding libclang 14.0.1 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for Keras-Preprocessing==1.1.2
# Best match: Keras-Preprocessing 1.1.2
# Adding Keras-Preprocessing 1.1.2 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for h5py==3.7.0
# Best match: h5py 3.7.0
# Adding h5py 3.7.0 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for google-pasta==0.2.0
# Best match: google-pasta 0.2.0
# Adding google-pasta 0.2.0 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for gast==0.4.0
# Best match: gast 0.4.0
# Adding gast 0.4.0 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for flatbuffers==1.12
# Best match: flatbuffers 1.12
# Adding flatbuffers 1.12 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for astunparse==1.6.3
# Best match: astunparse 1.6.3
# Adding astunparse 1.6.3 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for colorama==0.4.5
# Best match: colorama 0.4.5
# Adding colorama 0.4.5 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for rsa==4.8
# Best match: rsa 4.8
# Adding rsa 4.8 to easy-install.pth file
# Installing pyrsa-decrypt-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing pyrsa-decrypt.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing pyrsa-encrypt-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing pyrsa-encrypt.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing pyrsa-keygen-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing pyrsa-keygen.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing pyrsa-priv2pub-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing pyrsa-priv2pub.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing pyrsa-sign-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing pyrsa-sign.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing pyrsa-verify-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing pyrsa-verify.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for pyasn1==0.4.8
# Best match: pyasn1 0.4.8
# Adding pyasn1 0.4.8 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for pyasn1-modules==0.2.8
# Best match: pyasn1-modules 0.2.8
# Adding pyasn1-modules 0.2.8 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for urllib3==1.26.9
# Best match: urllib3 1.26.9
# Adding urllib3 1.26.9 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for certifi==2022.6.15
# Best match: certifi 2022.6.15
# Adding certifi 2022.6.15 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for google-auth==2.8.0
# Best match: google-auth 2.8.0
# Adding google-auth 2.8.0 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for idna==3.3
# Best match: idna 3.3
# Adding idna 3.3 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for charset-normalizer==2.0.12
# Best match: charset-normalizer 2.0.12
# Adding charset-normalizer 2.0.12 to easy-install.pth file
# Installing normalizer-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing normalizer.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for wheel==0.37.1
# Best match: wheel 0.37.1
# Adding wheel 0.37.1 to easy-install.pth file
# Installing wheel-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing wheel.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for Werkzeug==2.1.2
# Best match: Werkzeug 2.1.2
# Adding Werkzeug 2.1.2 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for tensorboard-plugin-wit==1.8.1
# Best match: tensorboard-plugin-wit 1.8.1
# Adding tensorboard-plugin-wit 1.8.1 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for tensorboard-data-server==0.6.1
# Best match: tensorboard-data-server 0.6.1
# Adding tensorboard-data-server 0.6.1 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for Markdown==3.3.7
# Best match: Markdown 3.3.7
# Adding Markdown 3.3.7 to easy-install.pth file
# Installing markdown_py-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing markdown_py.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for google-auth-oauthlib==0.4.6
# Best match: google-auth-oauthlib 0.4.6
# Adding google-auth-oauthlib 0.4.6 to easy-install.pth file
# Installing google-oauthlib-tool-script.py script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
# Installing google-oauthlib-tool.exe script to c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for zipp==3.8.0
# Best match: zipp 3.8.0
# Adding zipp 3.8.0 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for pywin32==304
# Best match: pywin32 304
# Adding pywin32 304 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for cachetools==5.2.0
# Best match: cachetools 5.2.0
# Adding cachetools 5.2.0 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for importlib-metadata==4.11.4
# Best match: importlib-metadata 4.11.4
# Adding importlib-metadata 4.11.4 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for requests-oauthlib==1.3.1
# Best match: requests-oauthlib 1.3.1
# Adding requests-oauthlib 1.3.1 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Searching for oauthlib==3.2.0
# Best match: oauthlib 3.2.0
# Adding oauthlib 3.2.0 to easy-install.pth file
#
# Using c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages
# Finished processing dependencies for object-detection==0.1
# zip_safe flag not set; analyzing archive contents...
# object_detection.core.__pycache__.densepose_ops.cpython-39: module references __file__
# object_detection.core.__pycache__.preprocessor.cpython-39: module MAY be using inspect.stack
# object_detection.utils.__pycache__.autoaugment_utils.cpython-39: module MAY be using inspect.stack
# warning: no previously-included files matching 'tests\*' found anywhere in distribution
# warning: no previously-included files matching '*' found under directory 'tests'
# zip_safe flag not set; analyzing archive contents...
# promise.pyutils.__pycache__.version.cpython-39: module references __file__
# zip_safe flag not set; analyzing archive contents...
# Obtaining file:///C:/Users/David/PythonProjects/test_environment/Tensorflow/models/research/slim
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from slim==0.1) (1.16.0)
# Requirement already satisfied: tf-slim>=1.1 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from slim==0.1) (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in c:\users\david\pythonprojects\test_environment\robot_cell_env\lib\site-packages (from tf-slim>=1.1->slim==0.1) (1.1.0)
# Installing collected packages: slim
#   Attempting uninstall: slim
#     Found existing installation: slim 0.1
#     Uninstalling slim-0.1:
#       Successfully uninstalled slim-0.1
#   Running setup.py develop for slim
# Successfully installed slim-0.1

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# Running tests under Python 3.9.12: c:\Users\David\PythonProjects\test_environment\robot_cell_env\Scripts\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-06-20 16:44:56.767745: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-20 16:44:57.136485: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5472 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# c:\Users\David\PythonProjects\test_environment\robot_cell_env\lib\site-packages\object_detection-0.1-py3.9.egg\object_detection\builders\model_builder.py:1102: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0620 16:44:57.490524  3500 model_builder.py:1102] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.86s
# I0620 16:44:57.620583  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.86s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.49s
# I0620 16:44:58.114765  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.49s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.21s
# I0620 16:44:58.323133  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.21s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.13s
# I0620 16:44:58.452168  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.13s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 0.97s
# I0620 16:44:59.417318  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 0.97s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0620 16:44:59.418525  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.01s
# I0620 16:44:59.431514  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0620 16:44:59.440669  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I0620 16:44:59.448742  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.05s
# I0620 16:44:59.501712  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.05s
# I0620 16:44:59.549676  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.05s
# I0620 16:44:59.599463  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.05s
# I0620 16:44:59.650107  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.05s
efficientnet_model.py:143] round_filter input=1280 output=2304
# I0620 16:45:09.254961  3500 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0620 16:45:09.308486  3500 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0620 16:45:09.308486  3500 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0620 16:45:09.308486  3500 ssd_efficientnet_bifpn_feature_extractor.py:148] EfficientDet BiFPN num iterations: 8
# I0620 16:45:09.308486  3500 efficientnet_model.py:143] round_filter input=32 output=64
# I0620 16:45:09.319842  3500 efficientnet_model.py:143] round_filter input=32 output=64
# I0620 16:45:09.319842  3500 efficientnet_model.py:143] round_filter input=16 output=32
# I0620 16:45:09.462254  3500 efficientnet_model.py:143] round_filter input=16 output=32
# I0620 16:45:09.462254  3500 efficientnet_model.py:143] round_filter input=24 output=48
# I0620 16:45:09.749675  3500 efficientnet_model.py:143] round_filter input=24 output=48
# I0620 16:45:09.749675  3500 efficientnet_model.py:143] round_filter input=40 output=80
# I0620 16:45:10.030764  3500 efficientnet_model.py:143] round_filter input=40 output=80
# I0620 16:45:10.030764  3500 efficientnet_model.py:143] round_filter input=80 output=160
# I0620 16:45:10.450478  3500 efficientnet_model.py:143] round_filter input=80 output=160
# I0620 16:45:10.450478  3500 efficientnet_model.py:143] round_filter input=112 output=224
# I0620 16:45:10.978796  3500 efficientnet_model.py:143] round_filter input=112 output=224
# I0620 16:45:10.978796  3500 efficientnet_model.py:143] round_filter input=192 output=384
# I0620 16:45:11.516011  3500 efficientnet_model.py:143] round_filter input=192 output=384
# I0620 16:45:11.516011  3500 efficientnet_model.py:143] round_filter input=320 output=640
# I0620 16:45:11.689359  3500 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0620 16:45:11.699444  3500 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 12.04s
# I0620 16:45:11.761038  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 12.04s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0620 16:45:11.765098  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0620 16:45:11.765098  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0620 16:45:11.766101  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0620 16:45:11.766101  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0620 16:45:11.767098  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0620 16:45:11.767098  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0620 16:45:11.768098  3500 test_util.py:2458] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 15.003s
#
# OK (skipped=1)

# %%
# !pip list
# Out:
# Package                       Version             Editable project location
# ----------------------------- ------------------- ------------------------------------------------------------------------------
# absl-py                       1.1.0
# anyio                         3.6.1
# apache-beam                   2.40.0rc1
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asttokens                     2.0.5
# astunparse                    1.6.3
# attrs                         21.4.0
# avro-python3                  1.10.2
# Babel                         2.10.3
# backcall                      0.2.0
# beautifulsoup4                4.11.1
# bleach                        5.0.0
# cachetools                    5.2.0
# certifi                       2022.6.15
# cffi                          1.15.0
# charset-normalizer            2.0.12
# cloudpickle                   2.1.0
# colorama                      0.4.5
# contextlib2                   21.6.0
# crcmod                        1.7
# cryptography                  37.0.2
# cvzone                        1.5.2
# cycler                        0.11.0
# Cython                        3.0.0a10
# debugpy                       1.6.0
# decorator                     5.1.1
# defusedxml                    0.7.1
# deprecation                   2.1.0
# dill                          0.3.1.1
# dm-tree                       0.1.7
# docopt                        0.6.2
# entrypoints                   0.4
# etils                         0.6.0
# executing                     0.8.3
# fastavro                      1.5.1
# fastjsonschema                2.15.3
# flatbuffers                   1.12
# fonttools                     4.33.3
# gast                          0.4.0
# gin-config                    0.5.0
# google-api-core               2.8.2
# google-api-python-client      2.51.0
# google-auth                   2.8.0
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          0.4.6
# google-pasta                  0.2.0
# googleapis-common-protos      1.56.3b1
# grpcio                        1.47.0rc1
# h5py                          3.7.0
# hdfs                          2.7.0
# httplib2                      0.20.4
# idna                          3.3
# importlib-metadata            4.11.4
# importlib-resources           5.8.0
# ipykernel                     6.15.0
# ipython                       8.4.0
# ipython-genutils              0.2.0
# ipywidgets                    7.7.0
# jedi                          0.18.1
# Jinja2                        3.1.2
# joblib                        1.1.0
# json5                         0.9.8
# jsonschema                    4.6.0
# jupyter-client                7.3.4
# jupyter-core                  4.10.0
# jupyter-packaging             0.12.2
# jupyter-server                1.17.1
# jupyterlab                    3.4.3
# jupyterlab-pygments           0.2.2
# jupyterlab-server             2.14.0
# jupyterlab-widgets            1.1.0
# kaggle                        1.5.12
# keras                         2.8.0
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.4.3
# libclang                      14.0.1
# lvis                          0.5.3
# lxml                          4.9.0
# Markdown                      3.3.7
# MarkupSafe                    2.1.1
# matplotlib                    3.5.2
# matplotlib-inline             0.1.3
# mistune                       0.8.4
# nbclassic                     0.3.7
# nbclient                      0.6.4
# nbconvert                     6.5.0
# nbformat                      5.4.0
# nest-asyncio                  1.5.5
# notebook                      6.4.12
# notebook-shim                 0.1.0
# numpy                         1.22.4
# oauth2client                  4.1.3
# oauthlib                      3.2.0
# object-detection              0.1
# opcua                         0.98.13
# open3d                        0.15.1
# opencv-contrib-python         4.5.5.64
# opencv-python                 4.6.0.66
# opencv-python-headless        4.6.0.66
# opt-einsum                    3.3.0
# orjson                        3.7.2
# packaging                     21.3
# pandas                        1.4.2
# pandocfilters                 1.5.0
# parso                         0.8.3
# pickleshare                   0.7.5
# Pillow                        9.1.1
# pip                           22.1.2
# portalocker                   2.4.0
# prometheus-client             0.14.1
# promise                       2.3
# prompt-toolkit                3.0.29
# proto-plus                    1.20.6
# protobuf                      3.19.4
# psutil                        5.9.1
# pure-eval                     0.2.2
# py-cpuinfo                    8.0.0
# pyarrow                       7.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.4
# pycparser                     2.21
# pydot                         1.4.2
# Pygments                      2.12.0
# pymongo                       3.12.3
# pyparsing                     2.4.7
# pyrealsense2                  2.50.0.3812
# pyrsistent                    0.18.1
# python-dateutil               2.8.2
# python-slugify                6.1.2
# pytz                          2022.1
# pywin32                       304
# pywinpty                      2.0.5
# PyYAML                        5.4.1
# pyzmq                         23.2.0
# regex                         2022.6.2
# requests                      2.28.0
# requests-oauthlib             1.3.1
# rsa                           4.8
# sacrebleu                     2.1.0
# scikit-learn                  1.1.1
# scipy                         1.8.0
# Send2Trash                    1.8.0
# sentencepiece                 0.1.96
# seqeval                       1.2.2
# setuptools                    62.6.0
# six                           1.16.0
# slim                          0.1                 c:\users\david\pythonprojects\test_environment\tensorflow\models\research\slim
# sniffio                       1.2.0
# soupsieve                     2.3.2.post1
# stack-data                    0.3.0
# tabulate                      0.8.9
# tensorboard                   2.8.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.8.0
# tensorflow-addons             0.17.1
# tensorflow-datasets           4.6.0
# tensorflow-estimator          2.8.0
# tensorflow-gpu                2.8.0
# tensorflow-hub                0.12.0
# tensorflow-io                 0.26.0
# tensorflow-io-gcs-filesystem  0.26.0
# tensorflow-metadata           1.8.0
# tensorflow-model-optimization 0.7.2
# tensorflow-text               2.8.2
# termcolor                     1.1.0
# terminado                     0.15.0
# text-unidecode                1.3
# tf-estimator-nightly          2.8.0.dev2021122109
# tf-models-official            2.8.0
# tf-slim                       1.1.0
# threadpoolctl                 3.1.0
# tinycss2                      1.1.1
# toml                          0.10.2
# tomlkit                       0.11.0
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.3.0
# typeguard                     2.13.3
# typing_extensions             4.2.0
# uritemplate                   4.1.1
# urllib3                       1.26.9
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              1.3.3
# Werkzeug                      2.1.2
# wget                          3.2
# wheel                         0.37.1
# widgetsnbextension            3.6.0
# wrapt                         1.14.1
# zipp                          3.8.0

# %%
# Should work if everything is installed correctly
#sometimes everything is installed and kernel needs to be restarted
import object_detection

# %%
import cv2
#should be able to create aruco dict object
aruco = cv2.aruco.Dictionary_get(cv2.aruco.DICT_APRILTAG_36h11)
